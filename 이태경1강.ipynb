# %% [markdown]
# <a href="https://colab.research.google.com/github/1901280taekyeong/gi/blob/main/%EC%9D%B4%ED%83%9C%EA%B2%BD1%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
    print( "hello world")

# %%
greet()
# Out:
# hello world

# %%
def add(a,b):
  c=a+b
  return c
add (18,12)
# Out:
# 30

# %%
def multiply(a,b):
  c=a*b
  return c
multiply (15,4)
# Out:
# 60

# %%
def greet2(name):
 print('반갑습니다',name)
 print(name,'님은 파이썬의 세계로 오셨습니다') 
greet2('이태경')
# Out:
# 반갑습니다 이태경
# 이태경 님은 파이썬의 세계로 오셨습니다

# %%
def adder(num1,num2):
    sum=num1+num2
    return sum

    result = adder(16,18)
    print(result)

# %%
def adder(num1,num2):
    sum=num1+num2
    return sum
def main():
    print(adder(8,6))
main()
# Out:
# 14

# %%
result = eval(input("뭐든 넣어요 :"))
result
# Out:
# 뭐든 넣어요 :3+15*2-3
# 30

# %%
def ret():
  return 14

# %%
result=eval(input("뭐든 넣어요:"))
# Out:
# 뭐든 넣어요:ret()

# %%
print(result)
# Out:
# 14

# %%
def greet_three_times():
  print('hi')
  print('hi')
  print('hi')

# %%
greet_three_times()
# Out:
# hi
# hi
# hi

# %%
def greet_10(num):
  if (num>0):
    print('hi')
    num=num-1
    greet_10(num)

# %%
greet_10(3)
# Out:
# hi
# hi
# hi

# %%
import random
NUMBER_OF_TRIALS = 50000 #상수
numberOfHits = 0

for i in range(NUMBER_OF_TRIALS):
  x= random.random() *2-1
  y= random.random() *2-1

  if x*x+y*y<= 1:
    numberOfHits +=1
    pi = 4* numberOfHits/NUMBER_OF_TRIALS
    print("PI는",pi,"입니다.")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# PI는 2.74432 입니다.
# PI는 2.7444 입니다.
# PI는 2.74448 입니다.
# PI는 2.74456 입니다.
# PI는 2.74464 입니다.
# PI는 2.74472 입니다.
# PI는 2.7448 입니다.
# PI는 2.74488 입니다.
# PI는 2.74496 입니다.
# PI는 2.74504 입니다.
# PI는 2.74512 입니다.
# PI는 2.7452 입니다.
# PI는 2.74528 입니다.
# PI는 2.74536 입니다.
# PI는 2.74544 입니다.
# PI는 2.74552 입니다.
# PI는 2.7456 입니다.
# PI는 2.74568 입니다.
# PI는 2.74576 입니다.
# PI는 2.74584 입니다.
# PI는 2.74592 입니다.
# PI는 2.746 입니다.
# PI는 2.74608 입니다.
# PI는 2.74616 입니다.
# PI는 2.74624 입니다.
# PI는 2.74632 입니다.
# PI는 2.7464 입니다.
# PI는 2.74648 입니다.
# PI는 2.74656 입니다.
# PI는 2.74664 입니다.
# PI는 2.74672 입니다.
# PI는 2.7468 입니다.
# PI는 2.74688 입니다.
# PI는 2.74696 입니다.
# PI는 2.74704 입니다.
# PI는 2.74712 입니다.
# PI는 2.7472 입니다.
# PI는 2.74728 입니다.
# PI는 2.74736 입니다.
# PI는 2.74744 입니다.
# PI는 2.74752 입니다.
# PI는 2.7476 입니다.
# PI는 2.74768 입니다.
# PI는 2.74776 입니다.
# PI는 2.74784 입니다.
# PI는 2.74792 입니다.
# PI는 2.748 입니다.
# PI는 2.74808 입니다.
# PI는 2.74816 입니다.
# PI는 2.74824 입니다.
# PI는 2.74832 입니다.
# ...

# %%
count=0
while count <10:
  print("프로그래밍은 너무나 재미있습니다!!!!")
  count = count+1
# Out:
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!
# 프로그래밍은 너무나 재미있습니다!!!!

# %%
x=105
y=104
bool(x>y)
# Out:
# True

# %%
x=15
y=18
bool(x!=y)
# Out:
# True

# %%
money =1200
card = True
if money >= 3000 or card:
  print("택시를 타고 가라")

else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
bool(not True )
# Out:
# False

# %%
bool(not (True or False))
# Out:
# False

# %%
bool(not False)
# Out:
# True

# %%
bool((not True) or False)
# Out:
# False

# %%
bool((not False) or False)
# Out:
# True

# %%
bool((not False) or False)
# Out:
# True

# %%
1 in [1,2,3]
# Out:
# True

# %%
15 not in [1,2,3,4,5,6]
# Out:
# True

# %%
pocket = ['paper','cellphone','money']
if 'money' in pocket:
  print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
pocket = ['paper','money','cellphone']
if 'money' in pocket:
  pass
else:
 print("카트를 꺼내라")

# %%
pocket = ['paper','cellphone']
card=True
if 'money' in pocket:
  print("택시를 타고 가라")
elif card:
  print("택시를 타고 가라")
else:
  print("걸어가라")
# Out:
# 택시를 타고 가라
