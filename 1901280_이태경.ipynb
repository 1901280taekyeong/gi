# %% [markdown]
# <a href="https://colab.research.google.com/github/1901280taekyeong/gi/blob/main/1901280_%EC%9D%B4%ED%83%9C%EA%B2%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array([[7,15],[13,19],[12,12],[23,16],[17,8]])
data
# Out:
# array([[ 7, 15],
#        [13, 19],
#        [12, 12],
#        [23, 16],
#        [17,  8]])

# %%
plt.scatter(data[:,0],data[:,1])
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,30)
plt.ylim(0,25)

rows, columns=data.shape
for i in range(rows):
     plt.annotate(i+1, (data[i,0],data[i,1]))

# %%
scaler = StandardScaler()
scaler.fit(data)
data_std = scaler.transform(data)
print(data_std)
# Out:
# [[-1.38275492  0.26726124]
#  [-0.26160228  1.33630621]
#  [-0.44846106 -0.53452248]
#  [ 1.60698545  0.53452248]
#  [ 0.48583281 -1.60356745]]

# %%
plt.scatter(data_std[:,0], data_std[:,1])
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-2, 2)
plt.ylim(-2, 2)

rows, columns = data_std.shape
for i in range(rows):
  plt.annotate(i+1, (data_std[i,0], data_std[i,1]))

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data_std)
print(kmeans.labels_)
print(kmeans.cluster_centers_)
# Out:
# [0 0 0 1 1]
# [[-0.69760609  0.35634832]
#  [ 1.04640913 -0.53452248]]
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(data_std[:,0], data_std[:,1], c=kmeans.labels_, s=50)
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-2, 2)
plt.ylim(-2, 2)

rows, columns = data_std.shape

for i in range(rows):
  plt.annotate(i+1, (data_std[i,0], data_std[i,1]))  
 
plt.scatter(kmeans.cluster_centers_[:, 0], 
            kmeans.cluster_centers_[:, 1], 
            c='red', s=200, alpha=0.5);
for k in range(columns):
  plt.annotate(k, 
              (kmeans.cluster_centers_[k, 0], kmeans.cluster_centers_[k, 1]))

# %%
TWSS = {}
for k in range(1, 6): 
  model = KMeans(n_clusters=k)
  model.fit(data_std)
  TWSS[k] = model.inertia_

plt.plot(list(TWSS.keys()), list(TWSS.values()), marker='o')
plt.xlabel("Number of Clusters(K)")
plt.ylabel("TWSS")
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# 3장 연습문제
# 1-1 군집 1에 있는 d의 거리를 구하시오
#
# 답: 5
#
# 1-2 각 군집의 WSS를 구하고, TWSS를 구하시오
#
# 답:
#
# 1-3 k의 변화에 따른 TWSS는 다음과 같다. 군집의 수는 몇 개로 정하면 좋을까?
#
# 답: 4개

# %%
data = np.array([[1,4],[4,2],[3,7],[6,1],[2,5]])
data
# Out:
# array([[1, 4],
#        [4, 2],
#        [3, 7],
#        [6, 1],
#        [2, 5]])

# %%
plt.scatter(data[:,0],data[:,1])
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,20)
plt.ylim(0,20)

rows, columns=data.shape
for i in range(rows):
     plt.annotate(i+1, (data[i,0],data[i,1]))

# %%
scaler = StandardScaler()
scaler.fit(data)
data_std = scaler.transform(data)
print(data_std)
# Out:
# [[-1.27872403  0.09365858]
#  [ 0.46499055 -0.84292723]
#  [-0.11624764  1.4985373 ]
#  [ 1.62746694 -1.31122014]
#  [-0.69748583  0.56195149]]

# %%
plt.scatter(data_std[:,0], data_std[:,1])
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-2, 2)
plt.ylim(-2, 2)

rows, columns = data_std.shape
for i in range(rows):
  plt.annotate(i+1, (data_std[i,0], data_std[i,1]))

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data_std)
print(kmeans.labels_)
print(kmeans.cluster_centers_)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [0 1 0 1 0]
# [[-0.69748583  0.71804912]
#  [ 1.04622875 -1.07707368]]

# %%
plt.scatter(data_std[:,0], data_std[:,1], c=kmeans.labels_, s=50)
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(-2, 2)
plt.ylim(-2, 2)

rows, columns = data_std.shape

for i in range(rows):
  plt.annotate(i+1, (data_std[i,0], data_std[i,1]))  
 
plt.scatter(kmeans.cluster_centers_[:, 0], 
            kmeans.cluster_centers_[:, 1], 
            c='red', s=200, alpha=0.5);
for k in range(columns):
  plt.annotate(k, 
              (kmeans.cluster_centers_[k, 0], kmeans.cluster_centers_[k, 1]))

# %%
TWSS = {}

for k in range(1, 6):  
  model = KMeans(n_clusters=k)  
  model.fit(data_std)
  TWSS[k] = model.inertia_

plt.plot(list(TWSS.keys()), list(TWSS.values()), marker='o')
plt.xlabel("Number of Clusters(K)")
plt.ylabel("TWSS")
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# 2-1 다음 표의 빈칸을 계산하고, 각 개체를 군집1과 군집2에 할당하시오오
#
# 답: [[-1.27872403  0.09365858]
#  [ 0.46499055 -0.84292723]
#  [-0.11624764  1.4985373 ]
#  [ 1.62746694 -1.31122014]
#  [-0.69748583  0.56195149]]
#
# 할당된 군집집:[0 1 0 1 0]
#
# 2-2 할당된 군집들의 중심을 구하시오
#
# 답: 0= [ 1.04622875 -1.07707368] 1= [-0.69748583 0.71804912]
#
# 2-3 각 군집의 WSS와 TWSS를 구하시오
#
# 답:

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.array([[10,8],[20,4],[20,6],[40,4],[50,8]])
y_train= np.array([[100],[60],[50],[40],[100]])

# %%
X_test = np.array([[30,35]])

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=y_train)
plt.scatter(X_test[:,0],X_test[:,1],c='red',marker='D',s=100)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-eb06ac0c2f84> in <cell line: 1>()
# ----> 1 plt.scatter(X_train[:,0],X_train[:,1],c=y_train)
#       2 plt.scatter(X_test[:,0],X_test[:,1],c='red',marker='D',s=100)
#       3 plt.xlabel('x1')
#       4 plt.ylabel('x2')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import math

A = (1, 4)
B = (4, 2)

distance = math.sqrt((A[0] - B[0])**2 + (A[1] - B[1])**2)
print(distance)
# Out:
# 3.605551275463989

# %%
A = (1, 4)
B = (4, 2)

distance = abs(A[0] - B[0]) + abs(A[1] - B[1])
print(distance)
# Out:
# 5

# %%
A = (1, 4)
B = (4, 2)
p = 1

distance = ((abs(A[0] - B[0])**p + abs(A[1] - B[1])**p)**(1/p))
print(distance)
# Out:
# 5.0

# %%
A = (1, 4)
B = (4, 2)
p = 2

distance = ((abs(A[0] - B[0])**p + abs(A[1] - B[1])**p)**(1/p))
print(distance)
# Out:
# 3.605551275463989

# %%
import math

vector1 = (1, 4)
vector2 = (4, 2)

dot_product = vector1[0]*vector2[0] + vector1[1]*vector2[1]
magnitude_vector1 = math.sqrt(vector1[0]**2 + vector1[1]**2)
magnitude_vector2 = math.sqrt(vector2[0]**2 + vector2[1]**2)

cosine_similarity = dot_product / (magnitude_vector1 * magnitude_vector2)

print(cosine_similarity)
# Out:
# 0.6507913734559685

# %% [markdown]
# 2-1 유클리드 거리를 구하시오
#
# 답:3.605551275463989
#
# 2-2 맨하탄 거리를 구하시오
#
# 답:5
#
# 2-3 차수가1일때 민코브스키 거리를 구하시오
#
# 답:5 같다다
#
# 2-4 차수가 2일때 민코브스키 거리를 구하시오
#
# 답:루트 13으로 같다다
